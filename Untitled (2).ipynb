# %% [markdown]
# ## Number of mothers = children \ Fertility rate

# %%
import pandas as pd

# %%
df1 = pd.read_csv('Fertility rate.csv',error_bad_lines=False) 
df2 = pd.read_csv('population.csv',error_bad_lines=False)

# %%
df1.head(6)
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Fertility rate, total (births per woman)
# 1  Afghanistan          AFG  Fertility rate, total (births per woman)
# 2       Angola          AGO  Fertility rate, total (births per woman)
# 3      Albania          ALB  Fertility rate, total (births per woman)
# 4      Andorra          AND  Fertility rate, total (births per woman)
# 5   Arab World          ARB  Fertility rate, total (births per woman)
#
#    Indicator Code      1960      1961      1962      1963     1964      1965  \
# 0  SP.DYN.TFRT.IN  4.820000  4.655000  4.471000  4.271000  4.05900  3.842000
# 1  SP.DYN.TFRT.IN  7.450000  7.450000  7.450000  7.450000  7.45000  7.450000
# 2  SP.DYN.TFRT.IN  6.708000  6.790000  6.872000  6.954000  7.03600  7.116000
# 3  SP.DYN.TFRT.IN  6.489000  6.401000  6.282000  6.133000  5.96000  5.773000
# 4  SP.DYN.TFRT.IN       NaN       NaN       NaN       NaN      NaN       NaN
# ...

# %%
df2.head(6)
# Out:
#     Country Name Country Code                                Indicator Name  \
# 0          أروبا          ABW  عدد السكان في الفئة العمرية صفر-14، الإجمالي
# 1      أفغانستان          AFG  عدد السكان في الفئة العمرية صفر-14، الإجمالي
# 2         أنغولا          AGO  عدد السكان في الفئة العمرية صفر-14، الإجمالي
# 3        ألبانيا          ALB  عدد السكان في الفئة العمرية صفر-14، الإجمالي
# 4         أندورا          AND  عدد السكان في الفئة العمرية صفر-14، الإجمالي
# 5  العالم العربي          ARB  عدد السكان في الفئة العمرية صفر-14، الإجمالي
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  SP.POP.0014.TO     23770.0     24037.0     24135.0     24089.0     23925.0
# 1  SP.POP.0014.TO   3791401.0   3892776.0   3987207.0   4079606.0   4176101.0
# 2  SP.POP.0014.TO   2298276.0   2366959.0   2439522.0   2504084.0   2547459.0
# 3  SP.POP.0014.TO    646025.0    672912.0    699944.0    726429.0    751660.0
# ...

# %%
col1 = list(df1)
print(col1)
print('')
col2 = list(df2)
print(col2)
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', 'Unnamed: 65']
#
# ...

# %%
number_of_childern = df2['2018'][5]
number_of_Fertility_rate=df1['2018'][5] 
print(number_of_Fertility_rate)
print(number_of_childern)

# %%
Number_of_mothers = number_of_childern / number_of_Fertility_rate
Number_of_mothers
# Out:
# 42589075.74717456

# %% [markdown]
# ## number of mother that have childern from 0 to 15 years old is almost 43 million mothers

# %% [markdown]
# ##  according to undp in its report the number of childern and young people in Arab country is 191 million
# ## so, Number_of_mothers =  191 / 3.2= 59.6875 million
# ## so, I think the range of the mother in the Arab worlds is from 42million to 60million
# ## I depend on the Fertility_rate because it was almost 3 in the 18 past years
